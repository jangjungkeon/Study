# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# 시각화 라이브러리 설정
# %matplotlib inline

sns.set(style="whitegrid", palette="muted", font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

# Random_seed, labels 설정
RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %%
data = pd.read_csv("/Users/jk/git/Study/Data/kaggle_dataset/credit_fraud/creditcard.csv")
data.shape
# Out:
# (284807, 31)

# %%
data.isnull().sum().any()
# Out:
# False

# %%
count_classes = data["Class"].value_counts(sort=True)
count_classes.plot(kind="bar", rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
fraud_data = data[data.Class == 1]
normal_data = data[data.Class == 0]
fraud_data.shape
# Out:
# (492, 31)

# %%
fraud_data.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal_data.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, axes = plt.subplots(2, 1, sharex=True)
f.suptitle("Amount per transaction by class")

bins = 50

axes[0].hist(fraud_data.Amount, bins=bins)
axes[0].set_title("Fraud")

axes[1].hist(normal_data.Amount, bins=bins)
axes[1].set_title("Normal")

plt.xlabel("Amount ($)")
plt.ylabel("Number of Transactions")
plt.xlim((0, 20000))
plt.yscale("log")
plt.show()

# %%
f, axes = plt.subplots(2, 1, sharex=True)
f.suptitle("Time of transaction vs Amount by class")

axes[0].scatter(x=fraud_data.Time, y=fraud_data.Amount)
axes[0].set_title("Fraud")

axes[1].scatter(x=normal_data.Time, y=normal_data.Amount)
axes[1].set_title("Normal")

plt.xlabel("Time (in Seconds)")
plt.ylabel("Amount")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
from sklearn.preprocessing import StandardScaler

data = data.drop(["Time"], axis=1)

data["Amount"] = StandardScaler().fit_transform(data["Amount"].values.reshape(-1, 1))

# %%
train, test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
train = train[train.Class==0]
train = train.drop(["Class"], axis=1)

test_label = test.pop("Class")

train = train.values
test = test.values

train.shape
# Out:
# (227451, 29)

# %%
input_dim = train.shape[1]
encoding_dim = 14

input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
               activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)
decoder = Dense(int(encoding_dim / 2), activation="tanh")(encoder)
decoder = Dense(input_dim, activation="relu")(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 100
batch_size = 32
filepath_ck = "model_{epoch}"
log_dir = "./logs"

autoencoder.compile(optimizer="adam",
                   loss="mean_squared_error",
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath=filepath_ck,
                              verbose=1,
                               monitor="val_loss",
                               save_best_only=True)

tensorboard = TensorBoard(log_dir=log_dir,
                         histogram_freq=0,
                         write_graph=True,
                         write_images=True)

history = autoencoder.fit(train, train,
                         epochs=nb_epoch,
                         batch_size=batch_size,
                         shuffle=True,
                         validation_data=(test, test),
                         verbose=1,
                         callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 7108/7108 [==============================] - 21s 900us/step - loss: 0.8618 - accuracy: 0.5028 - val_loss: 0.8000 - val_accuracy: 0.6512
#
# Epoch 00001: val_loss improved from inf to 0.79997, saving model to model_1
# INFO:tensorflow:Assets written to: model_1/assets
# Epoch 2/100
# 7108/7108 [==============================] - 6s 826us/step - loss: 0.7492 - accuracy: 0.6535 - val_loss: 0.7816 - val_accuracy: 0.6679
#
# Epoch 00002: val_loss improved from 0.79997 to 0.78165, saving model to model_2
# INFO:tensorflow:Assets written to: model_2/assets
# Epoch 3/100
# 7108/7108 [==============================] - 6s 833us/step - loss: 0.7570 - accuracy: 0.6711 - val_loss: 0.7735 - val_accuracy: 0.6854
#
# Epoch 00003: val_loss improved from 0.78165 to 0.77353, saving model to model_3
# INFO:tensorflow:Assets written to: model_3/assets
# Epoch 4/100
# 7108/7108 [==============================] - 6s 848us/step - loss: 0.7425 - accuracy: 0.6833 - val_loss: 0.7700 - val_accuracy: 0.6913
#
# Epoch 00004: val_loss improved from 0.77353 to 0.77003, saving model to model_4
# INFO:tensorflow:Assets written to: model_4/assets
# Epoch 5/100
# 7108/7108 [==============================] - 6s 829us/step - loss: 0.7379 - accuracy: 0.6919 - val_loss: 0.7669 - val_accuracy: 0.7004
#
# Epoch 00005: val_loss improved from 0.77003 to 0.76688, saving model to model_5
# INFO:tensorflow:Assets written to: model_5/assets
# Epoch 6/100
# 7108/7108 [==============================] - 6s 834us/step - loss: 0.7359 - accuracy: 0.6980 - val_loss: 0.7642 - val_accuracy: 0.7089
#
# Epoch 00006: val_loss improved from 0.76688 to 0.76420, saving model to model_6
# INFO:tensorflow:Assets written to: model_6/assets
# Epoch 7/100
# 7108/7108 [==============================] - 6s 852us/step - loss: 0.7312 - accuracy: 0.7054 - val_loss: 0.7612 - val_accuracy: 0.7129
#
# Epoch 00007: val_loss improved from 0.76420 to 0.76117, saving model to model_7
# INFO:tensorflow:Assets written to: model_7/assets
# Epoch 8/100
# 7108/7108 [==============================] - 6s 838us/step - loss: 0.7169 - accuracy: 0.7102 - val_loss: 0.7596 - val_accuracy: 0.7185
#
# Epoch 00008: val_loss improved from 0.76117 to 0.75957, saving model to model_8
# INFO:tensorflow:Assets written to: model_8/assets
# Epoch 9/100
# 7108/7108 [==============================] - 6s 850us/step - loss: 0.7141 - accuracy: 0.7143 - val_loss: 0.7585 - val_accuracy: 0.7139
#
# Epoch 00009: val_loss improved from 0.75957 to 0.75851, saving model to model_9
# INFO:tensorflow:Assets written to: model_9/assets
# Epoch 10/100
# 7108/7108 [==============================] - 6s 856us/step - loss: 0.7140 - accuracy: 0.7153 - val_loss: 0.7548 - val_accuracy: 0.7087
#
# Epoch 00010: val_loss improved from 0.75851 to 0.75480, saving model to model_10
# INFO:tensorflow:Assets written to: model_10/assets
# Epoch 11/100
# 7108/7108 [==============================] - 6s 855us/step - loss: 0.7205 - accuracy: 0.7127 - val_loss: 0.7537 - val_accuracy: 0.7134
#
# Epoch 00011: val_loss improved from 0.75480 to 0.75371, saving model to model_11
# INFO:tensorflow:Assets written to: model_11/assets
# Epoch 12/100
# 7108/7108 [==============================] - 8s 1ms/step - loss: 0.7160 - accuracy: 0.7124 - val_loss: 0.7515 - val_accuracy: 0.7174
#
# Epoch 00012: val_loss improved from 0.75371 to 0.75150, saving model to model_12
# INFO:tensorflow:Assets written to: model_12/assets
# Epoch 13/100
# 7108/7108 [==============================] - 9s 1ms/step - loss: 0.7359 - accuracy: 0.7134 - val_loss: 0.7502 - val_accuracy: 0.7132
#
# Epoch 00013: val_loss improved from 0.75150 to 0.75021, saving model to model_13
# INFO:tensorflow:Assets written to: model_13/assets
# Epoch 14/100
# 7108/7108 [==============================] - 7s 921us/step - loss: 0.7162 - accuracy: 0.7116 - val_loss: 0.7491 - val_accuracy: 0.7095
#
# Epoch 00014: val_loss improved from 0.75021 to 0.74910, saving model to model_14
# INFO:tensorflow:Assets written to: model_14/assets
# Epoch 15/100
# 7108/7108 [==============================] - 6s 870us/step - loss: 0.7053 - accuracy: 0.7133 - val_loss: 0.7497 - val_accuracy: 0.7094
#
# Epoch 00015: val_loss did not improve from 0.74910
# Epoch 16/100
# 7108/7108 [==============================] - 7s 943us/step - loss: 0.7287 - accuracy: 0.7111 - val_loss: 0.7486 - val_accuracy: 0.7151
#
# Epoch 00016: val_loss improved from 0.74910 to 0.74864, saving model to model_16
# INFO:tensorflow:Assets written to: model_16/assets
# Epoch 17/100
# 7108/7108 [==============================] - 7s 975us/step - loss: 0.7090 - accuracy: 0.7126 - val_loss: 0.7477 - val_accuracy: 0.7043
#
# Epoch 00017: val_loss improved from 0.74864 to 0.74772, saving model to model_17
# INFO:tensorflow:Assets written to: model_17/assets
# Epoch 18/100
# 7108/7108 [==============================] - 7s 934us/step - loss: 0.7142 - accuracy: 0.7092 - val_loss: 0.7472 - val_accuracy: 0.7039
#
# Epoch 00018: val_loss improved from 0.74772 to 0.74716, saving model to model_18
# INFO:tensorflow:Assets written to: model_18/assets
# Epoch 19/100
# 7108/7108 [==============================] - 6s 884us/step - loss: 0.6997 - accuracy: 0.7079 - val_loss: 0.7467 - val_accuracy: 0.6920
#
# Epoch 00019: val_loss improved from 0.74716 to 0.74666, saving model to model_19
# INFO:tensorflow:Assets written to: model_19/assets
# Epoch 20/100
# 7108/7108 [==============================] - 6s 914us/step - loss: 0.7062 - accuracy: 0.7098 - val_loss: 0.7438 - val_accuracy: 0.7084
#
# Epoch 00020: val_loss improved from 0.74666 to 0.74378, saving model to model_20
# INFO:tensorflow:Assets written to: model_20/assets
# Epoch 21/100
# 7108/7108 [==============================] - 7s 950us/step - loss: 0.7162 - accuracy: 0.7127 - val_loss: 0.7446 - val_accuracy: 0.7177
#
# Epoch 00021: val_loss did not improve from 0.74378
# Epoch 22/100
# 7108/7108 [==============================] - 8s 1ms/step - loss: 0.7184 - accuracy: 0.7173 - val_loss: 0.7433 - val_accuracy: 0.7201
#
# Epoch 00022: val_loss improved from 0.74378 to 0.74327, saving model to model_22
# INFO:tensorflow:Assets written to: model_22/assets
# Epoch 23/100
# 7108/7108 [==============================] - 8s 1ms/step - loss: 0.7095 - accuracy: 0.7166 - val_loss: 0.7441 - val_accuracy: 0.7135
#
# Epoch 00023: val_loss did not improve from 0.74327
# Epoch 24/100
# 7108/7108 [==============================] - 8s 1ms/step - loss: 0.7062 - accuracy: 0.7190 - val_loss: 0.7430 - val_accuracy: 0.7254
#
# Epoch 00024: val_loss improved from 0.74327 to 0.74301, saving model to model_24
# INFO:tensorflow:Assets written to: model_24/assets
# Epoch 25/100
# 7108/7108 [==============================] - 9s 1ms/step - loss: 0.7128 - accuracy: 0.7187 - val_loss: 0.7439 - val_accuracy: 0.7128
#
# Epoch 00025: val_loss did not improve from 0.74301
# Epoch 26/100
# 7108/7108 [==============================] - 8s 1ms/step - loss: 0.7138 - accuracy: 0.7172 - val_loss: 0.7426 - val_accuracy: 0.7219
#
# Epoch 00026: val_loss improved from 0.74301 to 0.74256, saving model to model_26
# INFO:tensorflow:Assets written to: model_26/assets
# Epoch 27/100
# 7108/7108 [==============================] - 7s 972us/step - loss: 0.7453 - accuracy: 0.7191 - val_loss: 0.7417 - val_accuracy: 0.7204
#
# Epoch 00027: val_loss improved from 0.74256 to 0.74166, saving model to model_27
# INFO:tensorflow:Assets written to: model_27/assets
# Epoch 28/100
# 7108/7108 [==============================] - 7s 943us/step - loss: 0.7148 - accuracy: 0.7199 - val_loss: 0.7434 - val_accuracy: 0.7154
#
# Epoch 00028: val_loss did not improve from 0.74166
# Epoch 29/100
# 7108/7108 [==============================] - 7s 931us/step - loss: 0.7209 - accuracy: 0.7196 - val_loss: 0.7422 - val_accuracy: 0.7246
#
# Epoch 00029: val_loss did not improve from 0.74166
# Epoch 30/100
# 7108/7108 [==============================] - 6s 914us/step - loss: 0.7180 - accuracy: 0.7210 - val_loss: 0.7440 - val_accuracy: 0.7203
#
# Epoch 00030: val_loss did not improve from 0.74166
# Epoch 31/100
# 7108/7108 [==============================] - 7s 915us/step - loss: 0.7030 - accuracy: 0.7226 - val_loss: 0.7440 - val_accuracy: 0.7174
#
# Epoch 00031: val_loss did not improve from 0.74166
# Epoch 32/100
# 7108/7108 [==============================] - 7s 942us/step - loss: 0.7223 - accuracy: 0.7207 - val_loss: 0.7433 - val_accuracy: 0.7249
#
# Epoch 00032: val_loss did not improve from 0.74166
# Epoch 33/100
# 7108/7108 [==============================] - 6s 896us/step - loss: 0.7184 - accuracy: 0.7204 - val_loss: 0.7419 - val_accuracy: 0.7225
#
# Epoch 00033: val_loss did not improve from 0.74166
# Epoch 34/100
# 7108/7108 [==============================] - 6s 837us/step - loss: 0.7031 - accuracy: 0.7203 - val_loss: 0.7482 - val_accuracy: 0.7190
#
# Epoch 00034: val_loss did not improve from 0.74166
# Epoch 35/100
# 7108/7108 [==============================] - 6s 839us/step - loss: 0.7163 - accuracy: 0.7219 - val_loss: 0.7416 - val_accuracy: 0.7228
#
# Epoch 00035: val_loss improved from 0.74166 to 0.74165, saving model to model_35
# INFO:tensorflow:Assets written to: model_35/assets
# Epoch 36/100
# 7108/7108 [==============================] - 6s 843us/step - loss: 0.7089 - accuracy: 0.7209 - val_loss: 0.7425 - val_accuracy: 0.7235
#
# Epoch 00036: val_loss did not improve from 0.74165
# Epoch 37/100
# 7108/7108 [==============================] - 6s 904us/step - loss: 0.7113 - accuracy: 0.7216 - val_loss: 0.7430 - val_accuracy: 0.7169
#
# Epoch 00037: val_loss did not improve from 0.74165
# Epoch 38/100
# 7108/7108 [==============================] - 6s 912us/step - loss: 0.7003 - accuracy: 0.7230 - val_loss: 0.7430 - val_accuracy: 0.7155
#
# Epoch 00038: val_loss did not improve from 0.74165
# Epoch 39/100
# 7108/7108 [==============================] - 6s 859us/step - loss: 0.6940 - accuracy: 0.7222 - val_loss: 0.7440 - val_accuracy: 0.7276
#
# Epoch 00039: val_loss did not improve from 0.74165
# Epoch 40/100
# 7108/7108 [==============================] - 6s 844us/step - loss: 0.7234 - accuracy: 0.7233 - val_loss: 0.7442 - val_accuracy: 0.7160
#
# Epoch 00040: val_loss did not improve from 0.74165
# Epoch 41/100
# 7108/7108 [==============================] - 6s 887us/step - loss: 0.7077 - accuracy: 0.7252 - val_loss: 0.7435 - val_accuracy: 0.7158
#
# Epoch 00041: val_loss did not improve from 0.74165
# Epoch 42/100
# 7108/7108 [==============================] - 6s 914us/step - loss: 0.7053 - accuracy: 0.7213 - val_loss: 0.7430 - val_accuracy: 0.7201
#
# Epoch 00042: val_loss did not improve from 0.74165
# Epoch 43/100
# 7108/7108 [==============================] - 6s 877us/step - loss: 0.6996 - accuracy: 0.7220 - val_loss: 0.7430 - val_accuracy: 0.7113
#
# Epoch 00043: val_loss did not improve from 0.74165
# Epoch 44/100
# 7108/7108 [==============================] - 6s 865us/step - loss: 0.7050 - accuracy: 0.7211 - val_loss: 0.7424 - val_accuracy: 0.7261
#
# Epoch 00044: val_loss did not improve from 0.74165
# Epoch 45/100
# 7108/7108 [==============================] - 6s 872us/step - loss: 0.7015 - accuracy: 0.7239 - val_loss: 0.7447 - val_accuracy: 0.7196
#
# Epoch 00045: val_loss did not improve from 0.74165
# Epoch 46/100
# 7108/7108 [==============================] - 6s 886us/step - loss: 0.7165 - accuracy: 0.7216 - val_loss: 0.7432 - val_accuracy: 0.7221
#
# Epoch 00046: val_loss did not improve from 0.74165
# Epoch 47/100
# 7108/7108 [==============================] - 6s 884us/step - loss: 0.7327 - accuracy: 0.7231 - val_loss: 0.7419 - val_accuracy: 0.7265
#
# Epoch 00047: val_loss did not improve from 0.74165
# Epoch 48/100
# 7108/7108 [==============================] - 6s 864us/step - loss: 0.7036 - accuracy: 0.7220 - val_loss: 0.7428 - val_accuracy: 0.7223
#
# Epoch 00048: val_loss did not improve from 0.74165
# Epoch 49/100
# 7108/7108 [==============================] - 6s 886us/step - loss: 0.7173 - accuracy: 0.7220 - val_loss: 0.7427 - val_accuracy: 0.7223
#
# Epoch 00049: val_loss did not improve from 0.74165
# Epoch 50/100
# 7108/7108 [==============================] - 6s 876us/step - loss: 0.6971 - accuracy: 0.7228 - val_loss: 0.7429 - val_accuracy: 0.7174
#
# Epoch 00050: val_loss did not improve from 0.74165
# Epoch 51/100
# 7108/7108 [==============================] - 6s 885us/step - loss: 0.7102 - accuracy: 0.7239 - val_loss: 0.7423 - val_accuracy: 0.7174
#
# Epoch 00051: val_loss did not improve from 0.74165
# Epoch 52/100
# 7108/7108 [==============================] - 6s 891us/step - loss: 0.6948 - accuracy: 0.7213 - val_loss: 0.7418 - val_accuracy: 0.7203
#
# Epoch 00052: val_loss did not improve from 0.74165
# Epoch 53/100
# 7108/7108 [==============================] - 6s 861us/step - loss: 0.6970 - accuracy: 0.7222 - val_loss: 0.7414 - val_accuracy: 0.7259
#
# Epoch 00053: val_loss improved from 0.74165 to 0.74142, saving model to model_53
# INFO:tensorflow:Assets written to: model_53/assets
# Epoch 54/100
# 7108/7108 [==============================] - 6s 850us/step - loss: 0.7260 - accuracy: 0.7230 - val_loss: 0.7416 - val_accuracy: 0.7266
#
# Epoch 00054: val_loss did not improve from 0.74142
# Epoch 55/100
# 7108/7108 [==============================] - 6s 867us/step - loss: 0.7266 - accuracy: 0.7231 - val_loss: 0.7442 - val_accuracy: 0.7222
#
# Epoch 00055: val_loss did not improve from 0.74142
# Epoch 56/100
# 7108/7108 [==============================] - 6s 907us/step - loss: 0.6963 - accuracy: 0.7248 - val_loss: 0.7429 - val_accuracy: 0.7165
#
# Epoch 00056: val_loss did not improve from 0.74142
# Epoch 57/100
# 7108/7108 [==============================] - 7s 915us/step - loss: 0.7168 - accuracy: 0.7241 - val_loss: 0.7480 - val_accuracy: 0.7160
#
# Epoch 00057: val_loss did not improve from 0.74142
# Epoch 58/100
# 7108/7108 [==============================] - 6s 874us/step - loss: 0.7111 - accuracy: 0.7220 - val_loss: 0.7409 - val_accuracy: 0.7223
#
# Epoch 00058: val_loss improved from 0.74142 to 0.74094, saving model to model_58
# INFO:tensorflow:Assets written to: model_58/assets
# Epoch 59/100
# 7108/7108 [==============================] - 6s 879us/step - loss: 0.7103 - accuracy: 0.7222 - val_loss: 0.7415 - val_accuracy: 0.7273
#
# Epoch 00059: val_loss did not improve from 0.74094
# Epoch 60/100
# 7108/7108 [==============================] - 6s 895us/step - loss: 0.7277 - accuracy: 0.7232 - val_loss: 0.7430 - val_accuracy: 0.7230
#
# Epoch 00060: val_loss did not improve from 0.74094
# Epoch 61/100
# 7108/7108 [==============================] - 7s 934us/step - loss: 0.6972 - accuracy: 0.7236 - val_loss: 0.7414 - val_accuracy: 0.7250
#
# Epoch 00061: val_loss did not improve from 0.74094
# Epoch 62/100
# 7108/7108 [==============================] - 6s 898us/step - loss: 0.7098 - accuracy: 0.7226 - val_loss: 0.7422 - val_accuracy: 0.7209
#
# Epoch 00062: val_loss did not improve from 0.74094
# Epoch 63/100
# 7108/7108 [==============================] - 7s 959us/step - loss: 0.6978 - accuracy: 0.7235 - val_loss: 0.7408 - val_accuracy: 0.7228
#
# Epoch 00063: val_loss improved from 0.74094 to 0.74079, saving model to model_63
# INFO:tensorflow:Assets written to: model_63/assets
# Epoch 64/100
# 7108/7108 [==============================] - 7s 952us/step - loss: 0.7194 - accuracy: 0.7207 - val_loss: 0.7411 - val_accuracy: 0.7205
#
# Epoch 00064: val_loss did not improve from 0.74079
# Epoch 65/100
# 7108/7108 [==============================] - 6s 866us/step - loss: 0.7008 - accuracy: 0.7238 - val_loss: 0.7421 - val_accuracy: 0.7228
#
# Epoch 00065: val_loss did not improve from 0.74079
# Epoch 66/100
# 7108/7108 [==============================] - 6s 852us/step - loss: 0.7108 - accuracy: 0.7242 - val_loss: 0.7414 - val_accuracy: 0.7221
#
# Epoch 00066: val_loss did not improve from 0.74079
# Epoch 67/100
# 7108/7108 [==============================] - 6s 890us/step - loss: 0.7073 - accuracy: 0.7206 - val_loss: 0.7432 - val_accuracy: 0.7235
#
# Epoch 00067: val_loss did not improve from 0.74079
# Epoch 68/100
# 7108/7108 [==============================] - 6s 914us/step - loss: 0.7128 - accuracy: 0.7217 - val_loss: 0.7416 - val_accuracy: 0.7125
#
# Epoch 00068: val_loss did not improve from 0.74079
# Epoch 69/100
# 7108/7108 [==============================] - 6s 905us/step - loss: 0.7151 - accuracy: 0.7247 - val_loss: 0.7412 - val_accuracy: 0.7241
#
# Epoch 00069: val_loss did not improve from 0.74079
# Epoch 70/100
# 7108/7108 [==============================] - 6s 852us/step - loss: 0.7279 - accuracy: 0.7215 - val_loss: 0.7419 - val_accuracy: 0.7202
#
# Epoch 00070: val_loss did not improve from 0.74079
# Epoch 71/100
# 7108/7108 [==============================] - 6s 902us/step - loss: 0.7049 - accuracy: 0.7214 - val_loss: 0.7408 - val_accuracy: 0.7281
#
# Epoch 00071: val_loss improved from 0.74079 to 0.74078, saving model to model_71
# INFO:tensorflow:Assets written to: model_71/assets
# Epoch 72/100
# 7108/7108 [==============================] - 6s 877us/step - loss: 0.7076 - accuracy: 0.7230 - val_loss: 0.7489 - val_accuracy: 0.7050
#
# Epoch 00072: val_loss did not improve from 0.74078
# Epoch 73/100
# 7108/7108 [==============================] - 6s 842us/step - loss: 0.7005 - accuracy: 0.7233 - val_loss: 0.7413 - val_accuracy: 0.7234
#
# Epoch 00073: val_loss did not improve from 0.74078
# Epoch 74/100
# 7108/7108 [==============================] - 6s 850us/step - loss: 0.7009 - accuracy: 0.7260 - val_loss: 0.7409 - val_accuracy: 0.7303
#
# Epoch 00074: val_loss did not improve from 0.74078
# Epoch 75/100
# 7108/7108 [==============================] - 6s 914us/step - loss: 0.7011 - accuracy: 0.7225 - val_loss: 0.7414 - val_accuracy: 0.7262
#
# Epoch 00075: val_loss did not improve from 0.74078
# Epoch 76/100
# 7108/7108 [==============================] - 6s 895us/step - loss: 0.7177 - accuracy: 0.7237 - val_loss: 0.7405 - val_accuracy: 0.7260
#
# Epoch 00076: val_loss improved from 0.74078 to 0.74049, saving model to model_76
# INFO:tensorflow:Assets written to: model_76/assets
# Epoch 77/100
# 7108/7108 [==============================] - 6s 831us/step - loss: 0.7009 - accuracy: 0.7247 - val_loss: 0.7420 - val_accuracy: 0.7221
#
# Epoch 00077: val_loss did not improve from 0.74049
# Epoch 78/100
# 7108/7108 [==============================] - 6s 833us/step - loss: 0.7089 - accuracy: 0.7260 - val_loss: 0.7408 - val_accuracy: 0.7313
#
# Epoch 00078: val_loss did not improve from 0.74049
# Epoch 79/100
# 7108/7108 [==============================] - 6s 857us/step - loss: 0.7175 - accuracy: 0.7247 - val_loss: 0.7414 - val_accuracy: 0.7221
#
# Epoch 00079: val_loss did not improve from 0.74049
# Epoch 80/100
# 7108/7108 [==============================] - 6s 863us/step - loss: 0.7048 - accuracy: 0.7251 - val_loss: 0.7423 - val_accuracy: 0.7215
#
# Epoch 00080: val_loss did not improve from 0.74049
# Epoch 81/100
# 7108/7108 [==============================] - 6s 842us/step - loss: 0.7007 - accuracy: 0.7256 - val_loss: 0.7406 - val_accuracy: 0.7233
#
# Epoch 00081: val_loss did not improve from 0.74049
# Epoch 82/100
# 7108/7108 [==============================] - 6s 827us/step - loss: 0.6947 - accuracy: 0.7245 - val_loss: 0.7410 - val_accuracy: 0.7290
#
# Epoch 00082: val_loss did not improve from 0.74049
# Epoch 83/100
# 7108/7108 [==============================] - 6s 860us/step - loss: 0.7043 - accuracy: 0.7269 - val_loss: 0.7414 - val_accuracy: 0.7255
#
# Epoch 00083: val_loss did not improve from 0.74049
# Epoch 84/100
# 7108/7108 [==============================] - 6s 883us/step - loss: 0.6992 - accuracy: 0.7252 - val_loss: 0.7422 - val_accuracy: 0.7259
#
# Epoch 00084: val_loss did not improve from 0.74049
# Epoch 85/100
# 7108/7108 [==============================] - 6s 853us/step - loss: 0.7021 - accuracy: 0.7246 - val_loss: 0.7407 - val_accuracy: 0.7283
#
# Epoch 00085: val_loss did not improve from 0.74049
# Epoch 86/100
# 7108/7108 [==============================] - 6s 821us/step - loss: 0.7034 - accuracy: 0.7267 - val_loss: 0.7409 - val_accuracy: 0.7235
#
# Epoch 00086: val_loss did not improve from 0.74049
# Epoch 87/100
# 7108/7108 [==============================] - 6s 834us/step - loss: 0.7137 - accuracy: 0.7244 - val_loss: 0.7407 - val_accuracy: 0.7269
#
# Epoch 00087: val_loss did not improve from 0.74049
# Epoch 88/100
# 7108/7108 [==============================] - 6s 861us/step - loss: 0.7042 - accuracy: 0.7248 - val_loss: 0.7420 - val_accuracy: 0.7204
#
# Epoch 00088: val_loss did not improve from 0.74049
# Epoch 89/100
# 7108/7108 [==============================] - 6s 870us/step - loss: 0.6963 - accuracy: 0.7239 - val_loss: 0.7414 - val_accuracy: 0.7308
#
# Epoch 00089: val_loss did not improve from 0.74049
# Epoch 90/100
# 7108/7108 [==============================] - 6s 852us/step - loss: 0.7081 - accuracy: 0.7269 - val_loss: 0.7414 - val_accuracy: 0.7272
#
# Epoch 00090: val_loss did not improve from 0.74049
# Epoch 91/100
# 7108/7108 [==============================] - 6s 846us/step - loss: 0.7275 - accuracy: 0.7231 - val_loss: 0.7411 - val_accuracy: 0.7189
#
# Epoch 00091: val_loss did not improve from 0.74049
# Epoch 92/100
# 7108/7108 [==============================] - 6s 848us/step - loss: 0.7232 - accuracy: 0.7239 - val_loss: 0.7419 - val_accuracy: 0.7171
#
# Epoch 00092: val_loss did not improve from 0.74049
# Epoch 93/100
# 7108/7108 [==============================] - 6s 889us/step - loss: 0.7106 - accuracy: 0.7262 - val_loss: 0.7401 - val_accuracy: 0.7250
#
# Epoch 00093: val_loss improved from 0.74049 to 0.74012, saving model to model_93
# INFO:tensorflow:Assets written to: model_93/assets
# Epoch 94/100
# 7108/7108 [==============================] - 6s 842us/step - loss: 0.7010 - accuracy: 0.7284 - val_loss: 0.7410 - val_accuracy: 0.7290
#
# Epoch 00094: val_loss did not improve from 0.74012
# Epoch 95/100
# 7108/7108 [==============================] - 6s 878us/step - loss: 0.7119 - accuracy: 0.7275 - val_loss: 0.7429 - val_accuracy: 0.7275
#
# Epoch 00095: val_loss did not improve from 0.74012
# Epoch 96/100
# 7108/7108 [==============================] - 6s 910us/step - loss: 0.7037 - accuracy: 0.7251 - val_loss: 0.7437 - val_accuracy: 0.7218
#
# Epoch 00096: val_loss did not improve from 0.74012
# Epoch 97/100
# 7108/7108 [==============================] - 7s 926us/step - loss: 0.7193 - accuracy: 0.7263 - val_loss: 0.7415 - val_accuracy: 0.7194
#
# Epoch 00097: val_loss did not improve from 0.74012
# Epoch 98/100
# 7108/7108 [==============================] - 7s 920us/step - loss: 0.7014 - accuracy: 0.7252 - val_loss: 0.7417 - val_accuracy: 0.7275
#
# Epoch 00098: val_loss did not improve from 0.74012
# Epoch 99/100
# 7108/7108 [==============================] - 6s 845us/step - loss: 0.7051 - accuracy: 0.7265 - val_loss: 0.7404 - val_accuracy: 0.7307
#
# Epoch 00099: val_loss did not improve from 0.74012
# Epoch 100/100
# 7108/7108 [==============================] - 6s 826us/step - loss: 0.7059 - accuracy: 0.7267 - val_loss: 0.7407 - val_accuracy: 0.7269
#
# Epoch 00100: val_loss did not improve from 0.74012

# %%
autoencoder = load_model("model_93")

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(['train', 'test'], loc="upper right")

# %%
predictions = autoencoder.predict(test)
mse = np.mean(np.power(test - predictions, 2), axis=1)
error_df = pd.DataFrame({"reconstruction_error": mse,
                        "true_class": test_label})

error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.739212      0.001720
# std                3.395099      0.041443
# min                0.045294      0.000000
# 25%                0.239819      0.000000
# 50%                0.381905      0.000000
# 75%                0.612452      0.000000
# max              254.950610      1.000000

# %%
# fig.add_subplot(111) = fig.add_subplot(1, 1, 1) 
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']==0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc, 
                             roc_curve, recall_score, classification_report, 
                             f1_score, precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title("Receiver Operating Characteristic")
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:0.4f}')
plt.legend(loc="lower right")
plt.plot([0,1], [0,1], 'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label="Precision-Recall curve")
plt.title("Recall vs Precision")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label="Threshold-Precision curve")
plt.title("Precision for different threshold values")
plt.xlabel("Threshhold")
plt.ylabel("Precision")
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label="Threshold-Recall curve")
plt.title("Recall for different threshold values")
plt.xlabel("Reconstruction error")
plt.ylabel("Recall")
plt.show()

# %%
threshold = 2.9

groups = error_df.groupby("true_class")
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker="o", ms=3.5, linestyle='',
           label="Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label="Threshold")
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show()

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel("True class")
plt.xlabel("Predicted class")
plt.show()
